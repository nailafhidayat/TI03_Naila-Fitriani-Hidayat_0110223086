# %% [markdown]
# <a href="https://colab.research.google.com/github/nailafhidayat/TI03_Naila-Fitriani-Hidayat_0110223086/blob/main/DATA_MINING_%5BPraktikum_Mandiri_11_OLS%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/Data Pelatihan 2024',sep = ',')
data
# Out:
#     ID   Nama  Umur     Gender  Nilai      Matkul    Tanggal  UTS  UAS
# 0    1   Budi    24  Laki-laki     85       Kimia   9/8/2023   90   80
# 1    2    Ani    21  Perempuan     77  Matematika  15/8/2023   75   80
# 2    3   Joko    20  Laki-laki     90     Biologi  15/8/2023   85   95
# 3    4   Siti    21  Perempuan     60  Matematika   9/8/2023   55   65
# 4    5   Agus    23  Laki-laki     77      Fisika   9/8/2023   80   75
# ..  ..    ...   ...        ...    ...         ...        ...  ...  ...
# 75  76  Fahmi    21  Laki-laki     80      Fisika   9/8/2023   88   72
# 76  77   Erna    20  Perempuan     83       Kimia  15/8/2023   83   83
# 77  78  Dimas    21  Laki-laki     82     Biologi   9/8/2023   91   73
# 78  79    Eka    22  Perempuan     75  Matematika  15/8/2023   73   77
# 79  80  Ricky    22  Laki-laki     78      Fisika  15/8/2023   74   83
#
# [80 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

x = data[["Nilai", "UTS"]].to_numpy()
y = data["UAS"].to_numpy()

x = sm.add_constant(x)
model_prediksi = sm.OLS(y, x).fit()
print(model_prediksi.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.035e+04
# Date:                Wed, 25 Dec 2024   Prob (F-statistic):           2.55e-94
# Time:                        06:59:43   Log-Likelihood:                -57.582
# No. Observations:                  80   AIC:                             121.2
# Df Residuals:                      77   BIC:                             128.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9913      0.799      1.241      0.218      -0.599       2.582
# ...

# %%
data1 = pd.read_csv('/content/Data Pelatihan (testing)',sep = ',')
x_tes = data1[["Nilai", "UTS"]].to_numpy()
y_real = data1["UAS"].to_numpy()
y_nama = data1["Nama"].to_numpy()
x_tes = sm.add_constant(x_tes)
y_pred = model_prediksi.predict(x_tes)

# %%
data = pd.DataFrame()
data["Nama Mahasiswa"]=y_nama
data["Nilai UAS Real"]=y_real
data["Nilai UAS Prediksi"]=y_pred
data["ERROR"]=data["Nilai UAS Real"]-data["Nilai UAS Prediksi"]
data["PERSEN PREDIKSI"]=1.0-(abs(data["ERROR"])/data["Nilai UAS Real"])
data["PERSEN"]=data["PERSEN PREDIKSI"]*100
display(data)
# Out:
#    Nama Mahasiswa  Nilai UAS Real  Nilai UAS Prediksi     ERROR  \
# 0           Merry              86           85.466157  0.533843
# 1           Rizal              87           87.449885 -0.449885
# 2            Tina              93           93.412818 -0.412818
# 3           Billy              72           71.559172  0.440828
# 4             Eva              72           71.559172  0.440828
# 5            Yudi              81           80.499656  0.500344
# 6            Vera              88           87.452496  0.547504
# 7            Deka              81           80.495088  0.504912
# 8            Dian              72           72.546468 -0.546468
# 9             Roy              91           90.429394  0.570606
# 10           Irma              85           85.465504 -0.465504
# 11          Wahyu              77           76.522410  0.477590
# 12           Sari              93           93.414776 -0.414776
# 13           Riko              85           84.472334  0.527666
# ...

# %%
data.to_csv('Data Hasil 2024.csv')
datasets = pd.read_csv("/content/Data Hasil 2024.csv")
datasets
# Out:
#     Unnamed: 0 Nama Mahasiswa  Nilai UAS Real  Nilai UAS Prediksi     ERROR  \
# 0            0          Merry              86           85.466157  0.533843
# 1            1          Rizal              87           87.449885 -0.449885
# 2            2           Tina              93           93.412818 -0.412818
# 3            3          Billy              72           71.559172  0.440828
# 4            4            Eva              72           71.559172  0.440828
# 5            5           Yudi              81           80.499656  0.500344
# 6            6           Vera              88           87.452496  0.547504
# 7            7           Deka              81           80.495088  0.504912
# 8            8           Dian              72           72.546468 -0.546468
# 9            9            Roy              91           90.429394  0.570606
# 10          10           Irma              85           85.465504 -0.465504
# ...

# %%
plt.figure(figsize=(12,6))
x = datasets.iloc[:, 0 ].values
plt.plot(x, datasets["Nilai UAS Real"], label = "Origin", color="b")
plt.plot(x, datasets["Nilai UAS Prediksi"], label = "Estimated", color="r")

plt.legend()
plt.xlabel("Simple ID")
plt.ylabel("Nilai UAS")
plt.title("Prediksi Nilai UAS Mahasiswa - OLS")
plt.show()
